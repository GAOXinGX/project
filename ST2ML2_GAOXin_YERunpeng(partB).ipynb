# %%
import pandas as pd
import os
#import unicodedata

# %% [markdown]
# ### Create fuctions to get positive and negative scores by using vader

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

def getpos(text):
    a = analyser.polarity_scores(text)
    return a['pos']

def getneg(text):
    a = analyser.polarity_scores(text)
    return a['neg']

# %% [markdown]
# ### Extract imformation and process data into clean dataframe

# %%
text = []
label = []
prezd = []
score_pos = []
score_neg = []

path = r"C:/Users/that/OneDrive - Efrei/s8/ST2ML2 - Advanced Machine Learning and Text Mining/TP project1/presidents-speeches"
president_names = os.listdir(path)

for president in president_names:
    speeches = os.listdir(path + "/" + president + "/speeches")
    num_speeches = len(speeches)
    i=1
    for speech in speeches:
        f = open(path + "/" +president + "/speeches/" + speech, "r")
        content = f.read()
        pos = getpos(content)
        neg = getneg(content)
        
        text.append(content)
        prezd.append(president)
        label.append(speech)
        score_pos.append(pos)
        score_neg.append(neg)
        
def delete(s):
    return s[2:]

text=list(map(delete,text))

def delete(s):
    return s[:-4] 

label=list(map(delete,label))

def split(s):
    return s.split("__")

label=list(map(split,label))

# %%
df = pd.DataFrame()
df['text'] = text
df['president'] = prezd
df['label'] = label
df['score_pos'] = score_pos
df['score_neg'] = score_neg

df1=df['label'].apply(pd.Series,index=['date','speech'])
df = df.join(df1)
df = df.drop(labels='label',axis=1)
df['date'] = pd.to_datetime(df['date'])
df.sort_values(by=['date'], inplace=True, ascending=True)
df = df.reset_index(drop=True)
df
# Out:
#                                                   text          president  \
# 0    Fellow Citizens of the Senate and the House of...  George Washington
# 1    Whereas it is the duty of all Nations to ackno...  George Washington
# 2    Fellow Citizens of the Senate and House of Rep...  George Washington
# 3     Fellow citizens of the Senate and House of Re...  George Washington
# 4     I the President of the United States, by my o...  George Washington
# ..                                                 ...                ...
# 370  PRESIDENT TRUMP:\xc2\xa0 Thank you very much.\...       Donald Trump
# 371  PRESIDENT TRUMP:\xc2\xa0 Thank you very much.\...       Donald Trump
# 372  Last night, the United States brought the worl...       Donald Trump
# 373  Hello, everybody.\xc2\xa0Well, thank you very ...       Donald Trump
# 374  As long as I am President of the United States...       Donald Trump
#
#      score_pos  score_neg       date  \
# 0        0.235      0.046 1789-04-30
# ...

# %%
#df.to_csv("df.csv",index=False)

# %%
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# ## All presidents

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=df["date"], y=df["score_pos"],
                    mode='lines',
                    name='positive score'))
fig.add_trace(go.Scatter(x=df["date"], y=df["score_neg"],
                    mode='lines',
                    name='negative score'))
fig.show()
# Out:
# <div>
#
#
#             <div id="f37e9651-86c8-4582-8ffe-71b1ca39d2d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f37e9651-86c8-4582-8ffe-71b1ca39d2d6")) {
#                     Plotly.newPlot(
#                         'f37e9651-86c8-4582-8ffe-71b1ca39d2d6',
# ...

# %% [markdown]
# ## George Washington

# %%
gw = df.loc[df['president'].isin(['George Washington'])]
fig = go.Figure()
fig.add_trace(go.Scatter(x=gw["date"], y=gw["score_pos"],
                    mode='lines',
                    name='positive score'))
fig.add_trace(go.Scatter(x=gw["date"], y=gw["score_neg"],
                    mode='lines',
                    name='negative score'))
fig.show()
# Out:
# <div>
#
#
#             <div id="157e719d-c1ff-49f6-b9ae-dad19fddb75d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("157e719d-c1ff-49f6-b9ae-dad19fddb75d")) {
#                     Plotly.newPlot(
#                         '157e719d-c1ff-49f6-b9ae-dad19fddb75d',
# ...

# %% [markdown]
# ## Thomas Jefferson

# %%
tj = df.loc[df['president'].isin(['Thomas Jefferson'])]
fig = go.Figure()
fig.add_trace(go.Scatter(x=tj["date"], y=tj["score_pos"],
                    mode='lines',
                    name='positive score'))
fig.add_trace(go.Scatter(x=tj["date"], y=tj["score_neg"],
                    mode='lines',
                    name='negative score'))
fig.show()
# Out:
# <div>
#
#
#             <div id="e380a917-0395-42ae-a13b-d0fe60f6bffa" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e380a917-0395-42ae-a13b-d0fe60f6bffa")) {
#                     Plotly.newPlot(
#                         'e380a917-0395-42ae-a13b-d0fe60f6bffa',
# ...

# %% [markdown]
# ## Andrew Jackson

# %%
aj = df.loc[df['president'].isin(['Andrew Jackson'])]
fig = go.Figure()
fig.add_trace(go.Scatter(x=aj["date"], y=aj["score_pos"],
                    mode='lines',
                    name='positive score'))
fig.add_trace(go.Scatter(x=aj["date"], y=aj["score_neg"],
                    mode='lines',
                    name='negative score'))
fig.show()
# Out:
# <div>
#
#
#             <div id="33bbfe33-1221-4f3d-a2fb-abf00ee233f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("33bbfe33-1221-4f3d-a2fb-abf00ee233f8")) {
#                     Plotly.newPlot(
#                         '33bbfe33-1221-4f3d-a2fb-abf00ee233f8',
# ...

# %% [markdown]
# ## Franklin D. Roosevelt

# %%
fdr = df.loc[df['president'].isin(['Franklin D. Roosevelt'])]
fig = go.Figure()
fig.add_trace(go.Scatter(x=fdr["date"], y=fdr["score_pos"],
                    mode='lines',
                    name='positive score'))
fig.add_trace(go.Scatter(x=fdr["date"], y=fdr["score_neg"],
                    mode='lines',
                    name='negative score'))
fig.show()
# Out:
# <div>
#
#
#             <div id="e482f75b-9be3-40ec-be1c-0886fbba97d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e482f75b-9be3-40ec-be1c-0886fbba97d3")) {
#                     Plotly.newPlot(
#                         'e482f75b-9be3-40ec-be1c-0886fbba97d3',
# ...

# %% [markdown]
# ## Richard M. Nixon

# %%
rmn = df.loc[df['president'].isin(['Richard M. Nixon'])]
fig = go.Figure()
fig.add_trace(go.Scatter(x=rmn["date"], y=rmn["score_pos"],
                    mode='lines',
                    name='positive score'))
fig.add_trace(go.Scatter(x=rmn["date"], y=rmn["score_neg"],
                    mode='lines',
                    name='negative score'))
fig.show()
# Out:
# <div>
#
#
#             <div id="60bb4ffd-d96f-40e7-bd43-737f5bfc0d27" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("60bb4ffd-d96f-40e7-bd43-737f5bfc0d27")) {
#                     Plotly.newPlot(
#                         '60bb4ffd-d96f-40e7-bd43-737f5bfc0d27',
# ...

# %% [markdown]
# ## Ronald Reagan

# %%
rr = df.loc[df['president'].isin(['Ronald Reagan'])]
fig = go.Figure()
fig.add_trace(go.Scatter(x=rr["date"], y=rr["score_pos"],
                    mode='lines',
                    name='positive score'))
fig.add_trace(go.Scatter(x=rr["date"], y=rr["score_neg"],
                    mode='lines',
                    name='negative score'))
fig.show()
# Out:
# <div>
#
#
#             <div id="563d9f0c-1372-47ca-9e4d-dd2556573358" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("563d9f0c-1372-47ca-9e4d-dd2556573358")) {
#                     Plotly.newPlot(
#                         '563d9f0c-1372-47ca-9e4d-dd2556573358',
# ...

# %% [markdown]
# ## George H. W. Bush

# %%
ghwb = df.loc[df['president'].isin(['George H. W. Bush'])]
fig = go.Figure()
fig.add_trace(go.Scatter(x=ghwb["date"], y=ghwb["score_pos"],
                    mode='lines',
                    name='positive score'))
fig.add_trace(go.Scatter(x=ghwb["date"], y=ghwb["score_neg"],
                    mode='lines',
                    name='negative score'))
fig.show()
# Out:
# <div>
#
#
#             <div id="d5ff9456-13c7-4d91-9dd4-a93436613181" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d5ff9456-13c7-4d91-9dd4-a93436613181")) {
#                     Plotly.newPlot(
#                         'd5ff9456-13c7-4d91-9dd4-a93436613181',
# ...

# %% [markdown]
# ## Bill Clinton

# %%
bc = df.loc[df['president'].isin(['Bill Clinton'])]
fig = go.Figure()
fig.add_trace(go.Scatter(x=bc["date"], y=bc["score_pos"],
                    mode='lines',
                    name='positive score'))
fig.add_trace(go.Scatter(x=bc["date"], y=bc["score_neg"],
                    mode='lines',
                    name='negative score'))
fig.show()
# Out:
# <div>
#
#
#             <div id="35c77719-a5ca-4361-ab15-e243df0c3ccf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("35c77719-a5ca-4361-ab15-e243df0c3ccf")) {
#                     Plotly.newPlot(
#                         '35c77719-a5ca-4361-ab15-e243df0c3ccf',
# ...

# %% [markdown]
# ## George W. Bush

# %%
gwb = df.loc[df['president'].isin(['George W. Bush'])]
fig = go.Figure()
fig.add_trace(go.Scatter(x=gwb["date"], y=gwb["score_pos"],
                    mode='lines',
                    name='positive score'))
fig.add_trace(go.Scatter(x=gwb["date"], y=gwb["score_neg"],
                    mode='lines',
                    name='negative score'))
fig.show()
# Out:
# <div>
#
#
#             <div id="b0feeec0-b49b-42ae-8a87-f9a326fb2302" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b0feeec0-b49b-42ae-8a87-f9a326fb2302")) {
#                     Plotly.newPlot(
#                         'b0feeec0-b49b-42ae-8a87-f9a326fb2302',
# ...

# %% [markdown]
# ## Barack Obama

# %%
bo = df.loc[df['president'].isin(['Barack Obama'])]
fig = go.Figure()
fig.add_trace(go.Scatter(x=bo["date"], y=bo["score_pos"],
                    mode='lines',
                    name='positive score'))
fig.add_trace(go.Scatter(x=bo["date"], y=bo["score_neg"],
                    mode='lines',
                    name='negative score'))
fig.show()
# Out:
# <div>
#
#
#             <div id="4a6c1ea8-47b6-4d95-9522-f4ce7c0528c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4a6c1ea8-47b6-4d95-9522-f4ce7c0528c7")) {
#                     Plotly.newPlot(
#                         '4a6c1ea8-47b6-4d95-9522-f4ce7c0528c7',
# ...

# %% [markdown]
# ## Donald Trump

# %%
tc = df.loc[df['president'].isin(['Donald Trump'])]
fig = go.Figure()
fig.add_trace(go.Scatter(x=tc["date"], y=tc["score_pos"],
                    mode='lines',
                    name='positive score'))
fig.add_trace(go.Scatter(x=tc["date"], y=tc["score_neg"],
                    mode='lines',
                    name='negative score'))
fig.show()
# Out:
# <div>
#
#
#             <div id="aed092e7-95b0-4084-8c3b-b9ba692f84f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("aed092e7-95b0-4084-8c3b-b9ba692f84f3")) {
#                     Plotly.newPlot(
#                         'aed092e7-95b0-4084-8c3b-b9ba692f84f3',
# ...
