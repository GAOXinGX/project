# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load in the dataframe
df = pd.read_csv("directory.csv", index_col=0)

# %%
# Looking at first 5 rows of the dataset
df.head()
df.tail()
# Out:
#            Store Number      Store Name Ownership Type  \
# Brand
# Starbucks  21401-212072             Rex       Licensed
# Starbucks  24010-226985        Panorama       Licensed
# Starbucks  47608-253804   Rosebank Mall       Licensed
# Starbucks  47640-253809    Menlyn Maine       Licensed
# Starbucks  47609-253286  Mall of Africa       Licensed
#
#                                               Street Address  \
# Brand
# Starbucks  141 Nguyễn Huệ, Quận 1, Góc đường Pasteur và L...
# Starbucks  SN-44, Tòa Nhà Panorama, 208 Trần Văn Trà, Quận 7
# Starbucks          Cnr Tyrwhitt and Cradock Avenue, Rosebank
# Starbucks  Shop 61B, Central Square, Cnr Aramist & Coroba...
# Starbucks             Shop 2077, Upper Level, Waterfall City
#
#                             City State/Province Country Postcode  \
# Brand
# Starbucks  Thành Phố Hồ Chí Minh             SG      VN    70000
# Starbucks  Thành Phố Hồ Chí Minh             SG      VN    70000
# Starbucks           Johannesburg             GT      ZA     2194
# Starbucks                 Menlyn             GT      ZA      181
# Starbucks                Midrand             GT      ZA     1682
#
#            Phone Number                        Timezone  Longitude  Latitude
# Brand
# Starbucks  08 3824 4668          GMT+000000 Asia/Saigon     106.70     10.78
# Starbucks  08 5413 8292          GMT+000000 Asia/Saigon     106.71     10.72
# Starbucks   27873500159  GMT+000000 Africa/Johannesburg      28.04    -26.15
# Starbucks           NaN  GMT+000000 Africa/Johannesburg      28.28    -25.79
# Starbucks   27873500215  GMT+000000 Africa/Johannesburg      28.11    -26.02

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25600 entries, Starbucks to Starbucks
# Data columns (total 12 columns):
# Store Number      25600 non-null object
# Store Name        25600 non-null object
# Ownership Type    25600 non-null object
# Street Address    25598 non-null object
# City              25585 non-null object
# State/Province    25600 non-null object
# Country           25600 non-null object
# Postcode          24078 non-null object
# Phone Number      18739 non-null object
# Timezone          25600 non-null object
# Longitude         25599 non-null float64
# Latitude          25599 non-null float64
# dtypes: float64(2), object(10)
# memory usage: 2.5+ MB

# %%
df.isnull().sum()
# Out:
# Store Number         0
# Store Name           0
# Ownership Type       0
# Street Address       2
# City                15
# State/Province       0
# Country              0
# Postcode          1522
# Phone Number      6861
# Timezone             0
# Longitude            1
# Latitude             1
# dtype: int64

# %%
df.drop(axis=1,columns='Phone Number',inplace=True)
df.dropna(axis=0, subset=['Longitude', 'Latitude'], inplace=True)
df.drop(axis=1,columns='Postcode',inplace=True)

# %%
df.isnull().sum()
# Out:
# Store Number       0
# Store Name         0
# Ownership Type     0
# Street Address     2
# City              15
# State/Province     0
# Country            0
# Timezone           0
# Longitude          0
# Latitude           0
# dtype: int64

# %%
col = 'Country'
vc1 = df[col].value_counts().reset_index()
vc1 = vc1.rename(columns = {col : "count", "index" : col})
vc1['percent'] = vc1['count'].apply(lambda x : 100*x/sum(vc1['count']))
vc1 = vc1.sort_values(col)

trace1 = go.Bar(x=vc1[col], y=vc1["count"], marker=dict(color="#a678de"))
data = [trace1]
layout = go.Layout(title="Countries", legend=dict(x=0.1, y=1.1, orientation="h"))
fig = go.Figure(data, layout=layout)
fig.show()
# Out:
# <div>
#
#
#             <div id="67bf680c-c3d2-4ecb-bb61-733e9f63c785" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("67bf680c-c3d2-4ecb-bb61-733e9f63c785")) {
#                     Plotly.newPlot(
#                         '67bf680c-c3d2-4ecb-bb61-733e9f63c785',
#                         [{"marker": {"color": "#a678de"}, "type": "bar", "x": ["AD", "AE", "AR", "AT", "AU", "AW", "AZ", "BE", "BG", "BH", "BN", "BO", "BR", "BS", "CA", "CH", "CL", "CN", "CO", "CR", "CW", "CY", "CZ", "DE", "DK", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HU", "ID", "IE", "IN", "JO", "JP", "KH", "KR", "KW", "KZ", "LB", "LU", "MA", "MC", "MX", "MY", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PR", "PT", "QA", "RO", "RU", "SA", "SE", "SG", "SK", "SV", "TH", "TR", "TT", "TW", "US", "VN", "ZA"], "y": [1, 144, 108, 18, 22, 3, 4, 19, 5, 21, 5, 4, 102, 10, 1468, 61, 96, 2734, 11, 11, 3, 10, 28, 160, 21, 31, 101, 8, 132, 901, 28, 7, 16, 268, 73, 88, 17, 1237, 4, 992, 106, 8, 29, 2, 9, 2, 579, 234, 59, 17, 24, 12, 5, 89, 298, 53, 24, 11, 18, 27, 109, 102, 18, 130, 3, 11, 289, 326, 3, 394, 13608, 25, 3]}],
#                         {"legend": {"orientation": "h", "x": 0.1, "y": 1.1}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar ...

# %%
first_ten_countries = df.Country.value_counts()[:10]
first_ten_countries
# Out:
# US    13608
# CN     2734
# CA     1468
# JP     1237
# KR      992
# GB      901
# MX      579
# TW      394
# TR      326
# PH      298
# Name: Country, dtype: int64

# %%
country_names =  first_ten_countries.index
country_values = first_ten_countries.values

# %%
plt.figure(figsize=(10,6))

sns.barplot(x=country_names, y=country_values, data = df, palette="BuGn_d")
plt.xlabel('Countries')
plt.ylabel('Size')
# Out:
# Text(0, 0.5, 'Size')

# %%
first_ten_cities = df.City.value_counts()[:10]
first_ten_cities
# Out:
# 上海市            542
# Seoul          242
# 北京市            234
# New York       232
# London         216
# Toronto        192
# Chicago        180
# Mexico City    180
# Seattle        156
# Las Vegas      156
# Name: City, dtype: int64

# %%
city_names =  first_ten_cities.index
city_values = first_ten_cities.values

# %%
from pylab import *
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus'] = False
plt.figure(figsize=(10,7))

fig, ax = plt.subplots(figsize=(16,8), dpi= 60)
ax.vlines(x=city_names, ymin=0, ymax=city_values, color='firebrick', alpha=0.7, linewidth=2)
ax.scatter(x=city_names, y=city_values, s=75, color='firebrick', alpha=0.7)

# %% [markdown]
# How is the ownership structured for stores

# %%
df['Ownership Type'].value_counts()
# Out:
# Company Owned    11932
# Licensed          9375
# Joint Venture     3975
# Franchise          317
# Name: Ownership Type, dtype: int64

# %%
col = 'Ownership Type'
vc1 = df[col].value_counts().reset_index()
vc1 = vc1.rename(columns = {col : "count", "index" : col})
vc1['percent'] = vc1['count'].apply(lambda x : 100*x/sum(vc1['count']))
vc1 = vc1.sort_values(col)

trace1 = go.Bar(x=vc1[col], y=vc1["count"], marker=dict(color="#6ad49b"))
data = [trace1]
layout = go.Layout(title="Ownership Type", legend=dict(x=0.1, y=1.1, orientation="h"))
fig = go.Figure(data, layout=layout)
fig.show()
# Out:
# <div>
#
#
#             <div id="58079fce-7823-4e2a-98bd-293971e187b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("58079fce-7823-4e2a-98bd-293971e187b2")) {
#                     Plotly.newPlot(
#                         '58079fce-7823-4e2a-98bd-293971e187b2',
#                         [{"marker": {"color": "#6ad49b"}, "type": "bar", "x": ["Company Owned", "Franchise", "Joint Venture", "Licensed"], "y": [11932, 317, 3975, 9375]}],
#                         {"legend": {"orientation": "h", "x": 0.1, "y": 1.1}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar ...

# %%
import plotly.graph_objects as go
from plotly.offline import init_notebook_mode, iplot
col = "Ownership Type"
grouped = df[col].value_counts().reset_index()
grouped = grouped.rename(columns = {col : "count", "index" : col})

## plot
trace = go.Pie(labels=grouped[col], values=grouped['count'], pull=[0.05, 0], marker=dict(colors=["#6ad49b", "#a678de"]))
layout = go.Layout(title="", height=400, legend=dict(x=0.01, y=1.1))
fig = go.Figure(data = [trace], layout = layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="672ad15b-3491-4269-85a9-b9c922228797" class="plotly-graph-div" style="height:400px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("672ad15b-3491-4269-85a9-b9c922228797")) {
#                     Plotly.newPlot(
#                         '672ad15b-3491-4269-85a9-b9c922228797',
#                         [{"labels": ["Company Owned", "Licensed", "Joint Venture", "Franchise"], "marker": {"colors": ["#6ad49b", "#a678de"]}, "pull": [0.05, 0], "type": "pie", "values": [11932, 9375, 3975, 317]}],
#                         {"height": 400, "legend": {"x": 0.01, "y": 1.1}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"} ...

# %% [markdown]
# So, most Starbucks stores are either owned by the company or licensed.

# %%
plt.figure(figsize=(10,6))
continents = df.Timezone.apply(lambda s: s.split('/')[0].split()[-1]).value_counts()

sns.barplot(continents.index, continents.values, palette="BuGn_d")
plt.title('Starbucks stores by Continent')
plt.ylabel('Number of Occurrences', fontsize=15)
plt.xlabel('Continent', fontsize=15)
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image
from termcolor import colored

wordcloud = (WordCloud( max_words=500, width=1440, height=1080, max_font_size=60, min_font_size=10, relative_scaling=0.5, mask=maskCity,background_color='white',font_path = '/System/Library/Fonts/PingFang.ttc').generate_from_frequencies(df['City'].value_counts()))

plt.figure(1,figsize=(15, 15))
plt.imshow(wordcloud,interpolation="gaussian")
plt.axis('off')
plt.show()

# %%
from wordcloud import WordCloud,STOPWORDS,ImageColorGenerator
bg_img = imread('cup.jpg')
wordcloud = (WordCloud( mask=bg_img, max_words=1000, width=1440, height=1080,background_color='white',font_path = '/System/Library/Fonts/PingFang.ttc').generate_from_frequencies(df['City'].value_counts()))

plt.figure(1,figsize=(15, 15))
plt.imshow(wordcloud,interpolation="gaussian")
plt.axis('off')
plt.show()

# %%
wordcloud = (WordCloud(max_words=50, width=1440, background_color='white',random_state = 30).generate_from_frequencies(df['Country'].value_counts()))

plt.figure(1,figsize=(50, 50))
plt.imshow(wordcloud,interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
conda create -n MYENVNAME python=3.6 fiona jupyter
# Out:
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /anaconda3/envs/MYENVNAME
#
#   added / updated specs:
#     - fiona
#     - jupyter
#     - python=3.6
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.1.1   |                0         132 KB  defaults
#     certifi-2019.11.28         |           py36_0         156 KB  defaults
#     cfitsio-3.470              |       hb33e7b4_2         1.4 MB  defaults
#     click-plugins-1.1.1        |             py_0          11 KB  defaults
#     fiona-1.8.11               |   py36heeaa653_0         1.0 MB  defaults
#     gdal-3.0.2                 |   py36hbe65578_0         1.6 MB  defaults
#     geos-3.8.0                 |       h0a44026_0         887 KB  defaults
#     geotiff-1.5.1              |       h0b0f252_0         130 KB  defaults
#     importlib_metadata-1.5.0   |           py36_0          47 KB  defaults
#     ipykernel-5.1.4            |   py36h39e3cac_0         168 KB  defaults
#     ipython-7.12.0             |   py36h5ca1d4c_0         1.1 MB  defaults
#     ipython_genutils-0.2.0     |           py36_0          40 KB  defaults
#     ipywidgets-7.5.1           |             py_0         107 KB  defaults
#     jedi-0.16.0                |           py36_0         787 KB  defaults
#     json-c-0.13.1              |       h3efe00b_0          64 KB  defaults
#     jsonschema-3.2.0           |           py36_0          93 KB  defaults
#     jupyter-1.0.0              |           py36_7           6 KB  defaults
#     jupyter_console-6.1.0      |             py_0          24 KB  defaults
#     kealib-1.4.7               |       hf5ed860_6         164 KB  defaults
#     libgdal-3.0.2              |       h42cfeda_0        17.3 MB  defaults
#     libnetcdf-4.6.1            |       hd5207e6_2         1.2 MB  defaults
#     libspatialite-4.3.0a       |       h5142b36_0         3.1 MB  defaults
#     lz4-c-1.8.1.2              |       h1de35cc_0         119 KB  defaults
#     munch-2.5.0                |             py_0          16 KB  defaults
#     ncurses-6.2                |       h0a44026_0        1024 KB  defaults
#     notebook-6.0.3             |           py36_0         6.3 MB  defaults
#     numpy-1.18.1               |   py36h7241aed_0           5 KB  defaults
#     numpy-base-1.18.1          |   py36h6575580_1         5.0 MB  defaults
#     pexpect-4.8.0              |           py36_0          84 KB  defaults
#     pip-20.0.2                 |           py36_1         1.9 MB  defaults
#     postgresql-11.2            |       h051b688_0         3.8 MB  defaults
#     proj-6.2.1                 |       hfd5b9e3_0        10.1 MB  defaults
#     pyrsistent-0.15.7          |   py36h1de35cc_0          91 KB  defaults
#     python-3.6.10              |       h359304d_0        20.6 MB  defaults
#     pyzmq-18.1.1               |   py36h0a44026_0         441 KB  defaults
#     setuptools-45.2.0          |           py36_0         655 KB  defaults
#     shapely-1.6.4              |   py36h6e5b138_0         322 KB  defaults
#     six-1.14.0                 |           py36_0          27 KB  defaults
#     tbb-2018.0.5               |       h04f5b5a_0         155 KB  defaults
#     terminado-0.8.3            |           py36_0          25 KB  defaults
#     tiledb-1.6.3               |       h29f752d_0         2.2 MB  defaults
#     tornado-6.0.3              |   py36h1de35cc_3         643 KB  defaults
#     wheel-0.34.2               |           py36_0          49 KB  defaults
#     widgetsnbextension-3.5.1   |           py36_0         1.8 MB  defaults
#     ------------------------------------------------------------
#                                            Total:        84.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   appnope            pkgs/main/osx-64::appnope-0.1.0-py36hf537a9a_0
#   attrs              pkgs/main/noarch::attrs-19.3.0-py_0
#   backcall           pkgs/main/osx-64::backcall-0.1.0-py36_0
#   blas               pkgs/main/osx-64::blas-1.0-mkl
#   bleach             pkgs/main/osx-64::bleach-3.1.0-py36_0
#   bzip2              pkgs/main/osx-64::bzip2-1.0.8-h1de35cc_0
#   ca-certificates    pkgs/main/osx-64::ca-certificates-2020.1.1-0
#   cairo              pkgs/main/osx-64::cairo-1.14.12-hc4e6be7_4
#   certifi            pkgs/main/osx-64::certifi-2019.11.28-py36_0
#   cfitsio            pkgs/main/osx-64::cfitsio-3.470-hb33e7b4_2
#   click              pkgs/main/osx-64::click-7.0-py36_0
#   click-plugins      pkgs/main/noarch::click-plugins-1.1.1-py_0
#   cligj              pkgs/main/osx-64::cligj-0.5.0-py36_0
#   curl               pkgs/main/osx-64::curl-7.67.0-ha441bb4_0
#   dbus               pkgs/main/osx-64::dbus-1.13.12-h90a0687_0
#   decorator          pkgs/main/noarch::decorator-4.4.1-py_0
#   defusedxml         pkgs/main/noarch::defusedxml-0.6.0-py_0
#   entrypoints        pkgs/main/osx-64::entrypoints-0.3-py36_0
#   expat              pkgs/main/osx-64::expat-2.2.6-h0a44026_0
#   fiona              pkgs/main/osx-64::fiona-1.8.11-py36heeaa653_0
#   fontconfig         pkgs/main/osx-64::fontconfig-2.13.0-h5d5b041_1
#   freetype           pkgs/main/osx-64::freetype-2.9.1-hb4e5f40_0
#   freexl             pkgs/main/osx-64::freexl-1.0.5-h1de35cc_0
#   gdal               pkgs/main/osx-64::gdal-3.0.2-py36hbe65578_0
#   geos               pkgs/main/osx-64::geos-3.8.0-h0a44026_0
#   geotiff            pkgs/main/osx-64::geotiff-1.5.1-h0b0f252_0
#   gettext            pkgs/main/osx-64::gettext-0.19.8.1-h15daf44_3
#   giflib             pkgs/main/osx-64::giflib-5.1.4-h1de35cc_1
#   glib               pkgs/main/osx-64::glib-2.63.1-hd977a24_0
#   hdf4               pkgs/main/osx-64::hdf4-4.2.13-h39711bb_2
#   hdf5               pkgs/main/osx-64::hdf5-1.10.4-hfa1e0ec_0
#   icu                pkgs/main/osx-64::icu-58.2-h4b95b61_1
#   importlib_metadata pkgs/main/osx-64::importlib_metadata-1.5.0-py36_0
#   intel-openmp       pkgs/main/osx-64::intel-openmp-2019.4-233
#   ipykernel          pkgs/main/osx-64::ipykernel-5.1.4-py36h39e3cac_0
#   ipython            pkgs/main/osx-64::ipython-7.12.0-py36h5ca1d4c_0
#   ipython_genutils   pkgs/main/osx-64::ipython_genutils-0.2.0-py36_0
#   ipywidgets         pkgs/main/noarch::ipywidgets-7.5.1-py_0
#   jedi               pkgs/main/osx-64::jedi-0.16.0-py36_0
#   jinja2             pkgs/main/noarch::jinja2-2.11.1-py_0
#   jpeg               pkgs/main/osx-64::jpeg-9b-he5867d9_2
#   json-c             pkgs/main/osx-64::json-c-0.13.1-h3efe00b_0
#   jsonschema         pkgs/main/osx-64::jsonschema-3.2.0-py36_0
#   jupyter            pkgs/main/osx-64::jupyter-1.0.0-py36_7
#   jupyter_client     pkgs/main/osx-64::jupyter_client-5.3.4-py36_0
#   jupyter_console    pkgs/main/noarch::jupyter_console-6.1.0-py_0
#   jupyter_core       pkgs/main/osx-64::jupyter_core-4.6.1-py36_0
#   kealib             pkgs/main/osx-64::kealib-1.4.7-hf5ed860_6
#   krb5               pkgs/main/osx-64::krb5-1.16.4-hddcf347_0
#   libboost           pkgs/main/osx-64::libboost-1.67.0-hebc422b_4
#   libcurl            pkgs/main/osx-64::libcurl-7.67.0-h051b688_0
#   libcxx             pkgs/main/osx-64::libcxx-4.0.1-hcfea43d_1
#   libcxxabi          pkgs/main/osx-64::libcxxabi-4.0.1-hcfea43d_1
#   libdap4            pkgs/main/osx-64::libdap4-3.19.1-h3d3e54a_0
#   libedit            pkgs/main/osx-64::libedit-3.1.20181209-hb402a30_0
#   libffi             pkgs/main/osx-64::libffi-3.2.1-h475c297_4
#   libgdal            pkgs/main/osx-64::libgdal-3.0.2-h42cfeda_0
#   libgfortran        pkgs/main/osx-64::libgfortran-3.0.1-h93005f0_2
#   libiconv           pkgs/main/osx-64::libiconv-1.15-hdd342a3_7
#   libkml             pkgs/main/osx-64::libkml-1.3.0-hbe12b63_4
#   libnetcdf          pkgs/main/osx-64::libnetcdf-4.6.1-hd5207e6_2
#   libpng             pkgs/main/osx-64::libpng-1.6.37-ha441bb4_0
#   libpq              pkgs/main/osx-64::libpq-11.2-h051b688_0
#   libsodium          pkgs/main/osx-64::libsodium-1.0.16-h3efe00b_0
#   libspatialite      pkgs/main/osx-64::libspatialite-4.3.0a-h5142b36_0
#   libssh2            pkgs/main/osx-64::libssh2-1.8.2-ha12b0ac_0
#   libtiff            pkgs/main/osx-64::libtiff-4.1.0-hcb84e12_0
#   libxml2            pkgs/main/osx-64::libxml2-2.9.9-hf6e021a_1
#   lz4-c              pkgs/main/osx-64::lz4-c-1.8.1.2-h1de35cc_0
#   markupsafe         pkgs/main/osx-64::markupsafe-1.1.1-py36h1de35cc_0
#   mistune            pkgs/main/osx-64::mistune-0.8.4-py36h1de35cc_0
#   mkl                pkgs/main/osx-64::mkl-2019.4-233
#   mkl-service        pkgs/main/osx-64::mkl-service-2.3.0-py36hfbe908c_0
#   mkl_fft            pkgs/main/osx-64::mkl_fft-1.0.15-py36h5e564d8_0
#   mkl_random         pkgs/main/osx-64::mkl_random-1.1.0-py36ha771720_0
#   munch              pkgs/main/noarch::munch-2.5.0-py_0
#   nbconvert          pkgs/main/osx-64::nbconvert-5.6.1-py36_0
#   nbformat           pkgs/main/noarch::nbformat-5.0.4-py_0
#   ncurses            pkgs/main/osx-64::ncurses-6.2-h0a44026_0
#   notebook           pkgs/main/osx-64::notebook-6.0.3-py36_0
#   numpy              pkgs/main/osx-64::numpy-1.18.1-py36h7241aed_0
#   numpy-base         pkgs/main/osx-64::numpy-base-1.18.1-py36h6575580_1
#   openjpeg           pkgs/main/osx-64::openjpeg-2.3.0-hb95cd4c_1
#   openssl            pkgs/main/osx-64::openssl-1.1.1d-h1de35cc_4
#   pandoc             pkgs/main/osx-64::pandoc-2.2.3.2-0
#   pandocfilters      pkgs/main/osx-64::pandocfilters-1.4.2-py36_1
#   parso              pkgs/main/noarch::parso-0.6.1-py_0
#   pcre               pkgs/main/osx-64::pcre-8.43-h0a44026_0
#   pexpect            pkgs/main/osx-64::pexpect-4.8.0-py36_0
#   pickleshare        pkgs/main/osx-64::pickleshare-0.7.5-py36_0
#   pip                pkgs/main/osx-64::pip-20.0.2-py36_1
#   pixman             pkgs/main/osx-64::pixman-0.38.0-h1de35cc_0
#   poppler            pkgs/main/osx-64::poppler-0.65.0-ha097c24_1
#   poppler-data       pkgs/main/osx-64::poppler-data-0.4.9-0
#   postgresql         pkgs/main/osx-64::postgresql-11.2-h051b688_0
#   proj               pkgs/main/osx-64::proj-6.2.1-hfd5b9e3_0
#   prometheus_client  pkgs/main/noarch::prometheus_client-0.7.1-py_0
#   prompt_toolkit     pkgs/main/noarch::prompt_toolkit-3.0.3-py_0
#   ptyprocess         pkgs/main/osx-64::ptyprocess-0.6.0-py36_0
#   pygments           pkgs/main/noarch::pygments-2.5.2-py_0
#   pyqt               pkgs/main/osx-64::pyqt-5.9.2-py36h655552a_2
#   pyrsistent         pkgs/main/osx-64::pyrsistent-0.15.7-py36h1de35cc_0
#   python             pkgs/main/osx-64::python-3.6.10-h359304d_0
#   python-dateutil    pkgs/main/noarch::python-dateutil-2.8.1-py_0
#   pyzmq              pkgs/main/osx-64::pyzmq-18.1.1-py36h0a44026_0
#   qt                 pkgs/main/osx-64::qt-5.9.7-h468cd18_1
#   qtconsole          pkgs/main/noarch::qtconsole-4.6.0-py_1
#   readline           pkgs/main/osx-64::readline-7.0-h1de35cc_5
#   send2trash         pkgs/main/osx-64::send2trash-1.5.0-py36_0
#   setuptools         pkgs/main/osx-64::setuptools-45.2.0-py36_0
#   shapely            pkgs/main/osx-64::shapely-1.6.4-py36h6e5b138_0
#   sip                pkgs/main/osx-64::sip-4.19.8-py36h0a44026_0
#   six                pkgs/main/osx-64::six-1.14.0-py36_0
#   sqlite             pkgs/main/osx-64::sqlite-3.31.1-ha441bb4_0
#   tbb                pkgs/main/osx-64::tbb-2018.0.5-h04f5b5a_0
#   terminado          pkgs/main/osx-64::terminado-0.8.3-py36_0
#   testpath           pkgs/main/noarch::testpath-0.4.4-py_0
#   tiledb             pkgs/main/osx-64::tiledb-1.6.3-h29f752d_0
#   tk                 pkgs/main/osx-64::tk-8.6.8-ha441bb4_0
#   tornado            pkgs/main/osx-64::tornado-6.0.3-py36h1de35cc_3
#   traitlets          pkgs/main/osx-64::traitlets-4.3.3-py36_0
#   wcwidth            pkgs/main/noarch::wcwidth-0.1.8-py_0
#   webencodings       pkgs/main/osx-64::webencodings-0.5.1-py36_1
#   wheel              pkgs/main/osx-64::wheel-0.34.2-py36_0
#   widgetsnbextension pkgs/main/osx-64::widgetsnbextension-3.5.1-py36_0
#   xerces-c           pkgs/main/osx-64::xerces-c-3.2.2-h44e365a_0
#   xz                 pkgs/main/osx-64::xz-5.2.4-h1de35cc_4
#   zeromq             pkgs/main/osx-64::zeromq-4.3.1-h0a44026_3
#   zipp               pkgs/main/noarch::zipp-2.2.0-py_0
#   zlib               pkgs/main/osx-64::zlib-1.2.11-h1de35cc_3
#   zstd               pkgs/main/osx-64::zstd-1.3.7-h5bba6e5_0
#
#
# Proceed ([y]/n)?

# %%
y
